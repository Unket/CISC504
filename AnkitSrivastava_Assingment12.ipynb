# %%
#1- Download the following dataset found at the following link
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
pd.read_excel('C:\Ankit\Harrisburg University\CIS 504\Certificate_of_Need_Applications__Beginning_1974.xlsx')
# Out:
#        CON Project Number  Facility Id  \
# 0                  191057       1098.0
# 1                  191056       1453.0
# 2                  191055       1692.0
# 3                  191054       1692.0
# 4                  191053        397.0
# 5                  191052       4068.0
# 6                  191051        409.0
# 7                  191050        756.0
# 8                  191049       1158.0
# 9                  191048       6334.0
# 10                 191047        128.0
# 11                 191046        831.0
# 12                 191045        413.0
# 13                 191044       6253.0
# 14                 191043       9470.0
# 15                 191042        116.0
# 16                 191041       1129.0
# 17                 191040       9263.0
# 18                 191039       8615.0
# 19                 191038        116.0
# 20                 191037       1326.0
# 21                 191036       1153.0
# 22                 191035          5.0
# ...

# %%
#2- What type of license is this Dataset shared under?
#this Data set is shared under CSV
dataframe1 = pd.read_excel('C:\Ankit\Harrisburg University\CIS 504\Certificate_of_Need_Applications__Beginning_1974.xlsx')
dataframe1.shape
# Out:
# (24381, 87)

# %%
#Omit all rows/observations with missing 'Total Project Cost' information
print (dataframe1['Total Project Cost'].unique())
# Out:
# [1.0324000e+04 2.4451595e+07 2.9163980e+06 ... 9.2200000e+07 6.5220000e+06
#  1.6365300e+08]

# %%
#4- Filter out the observations for the range of years 2014-2019
dataframe1 = pd.read_excel('C:\Ankit\Harrisburg University\CIS 504\Certificate_of_Need_Applications__Beginning_1974.xlsx')
filter_Range_Year = ((dataframe1["Application Received Year"] ==2014) | (dataframe1["Application Received Year"] ==2015)|(dataframe1["Application Received Year"] ==2016) | (dataframe1["Application Received Year"] ==2017)|(dataframe1["Application Received Year"] ==2018) | (dataframe1["Application Received Year"] ==2019))
filter_Range_Year_data = dataframe1[filter_Range_Year]
filter_Range_Year_data.head()
# Out:
#    CON Project Number  Facility Id  \
# 0              191057       1098.0
# 1              191056       1453.0
# 2              191055       1692.0
# 3              191054       1692.0
# 4              191053        397.0
#
#                                       Facility Name Project Description  \
# 0                        St Joseph's Medical Center                 NaN
# 1  Memorial Hospital for Cancer and Allied Diseases                 NaN
# 2           Woodhull Medical & Mental Health Center                 NaN
# 3           Woodhull Medical & Mental Health Center                 NaN
# 4                                 Oneida Healthcare                 NaN
#
#                                   Submission Type(s) Facility Type  \
# 0                Application - Administrative Review      Hospital
# 1                Application - Administrative Review      Hospital
# 2  Application - Limited Review - Minor Construction      Hospital
# ...

# %%
#5- Develop an informative plot of total project cost by facility type¶
# Next we use our plotting function to populate our newly created grids
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.pyplot as plt
import seaborn as sns
filter_Range_1 = pd.read_excel('C:\Ankit\Harrisburg University\CIS 504\Certificate_of_Need_Applications__Beginning_1974.xlsx')
#filter_Range_1 = (dataframe1) 
g = sns.FacetGrid(filter_Range_1, col="Total Project Cost")
g.map(plt.hist,"filter_Range_1")

# %%
#6- Stratify the plot you developed by year
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.pyplot as plt
import seaborn as sns
filter_Range_1 = pd.read_excel('C:\Ankit\Harrisburg University\CIS 504\Certificate_of_Need_Applications__Beginning_1974.xlsx')
#filter_Range_1 = (dataframe1) 
g = sns.FacetGrid(filter_Range_1, col="Application Received Year")
g.map(plt.hist,"filter_Range_1")

# %%
#7- Develop an informative visual plot of your choice
#6- Stratify the plot you developed by year
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.pyplot as plt
import seaborn as sns
filter_Range_1 = pd.read_excel('C:\Ankit\Harrisburg University\CIS 504\Certificate_of_Need_Applications__Beginning_1974.xlsx')
#filter_Range_1 = (dataframe1) 
g = sns.FacetGrid(filter_Range_1, col="Region")
g.map(plt.hist,"filter_Range_1")

# %%
#8- Interpret your findings
.
